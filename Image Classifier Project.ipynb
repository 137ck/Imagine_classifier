# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
from torch import nn, optim
import torch.nn.functional as F
import numpy as np
from torchvision import transforms,datasets,models

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
# transform_define = transforms.Compose([transforms.Resize(256),
#                                       transforms.CenterCrop(224),
#                                       transforms.ToTensor(),
#                                       transforms.Normalize([0.485,0.456,0.406],
#                                                            [0.229,0.224,0.225])])
train_transform = transforms.Compose( [transforms.Resize(256),
                                      transforms.RandomRotation(45),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485,0.456,0.406],
                                                           [0.229,0.224,0.225])]) 
test_transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485,0.456,0.406],
                                                           [0.229,0.224,0.225])])
valid_transform=test_transform
# TODO: Load the datasets with ImageFolder
# image_datasets = datasets.ImageFolder(data_dir,transform=transform_define)
train_datasets = datasets.ImageFolder(train_dir,transform=train_transform)
valid_datasets = datasets.ImageFolder(valid_dir,transform=valid_transform)
test_datasets=datasets.ImageFolder(test_dir,transform=valid_transform)

# TODO: Using the image datasets and the trainforms, define the dataloaders
# image_dataloader = torch.utils.data.DataLoader(image_datasets,batch_size=64,shuffle=True)
train_dataloader = torch.utils.data.DataLoader(train_datasets,batch_size=64,shuffle=True)
valid_dataloader = torch.utils.data.DataLoader(valid_datasets,batch_size=64)
test_dataloader = torch.utils.data.DataLoader(test_datasets,batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
device_choice=torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=models.densenet121(pretrained=True)
#model
for parameter in model.parameters():
    parameter.requires_grad=False

classifier_new= nn.Sequential(nn.Linear(1024,256),
                              nn.ReLU(),
                              nn.Dropout(p=0.2),
                              nn.Linear(256,102),
                              nn.LogSoftmax(dim=1))
model.classifier=classifier_new
criterion=nn.NLLLoss()
optimizer=optim.Adam(model.classifier.parameters(),lr=0.03)
model.to(device_choice)

nums=10
counts=0
present_loss=0
screen_every=30

for num in range(nums):
    for images,labels in train_dataloader:
        counts=counts+1
        images=images.to(device_choice)
        labels=labels.to(device_choice)
        optimizer.zero_grad()
        logps=model(images)
        loss=criterion(logps,labels)
        loss.backward()
        optimizer.step()
        present_loss=present_loss+loss.item()
        
        if counts % screen_every ==0:
            model.eval()
            valid_loss=0
            accuracy=0
            with torch.no_grad():
                for images,labels in valid_dataloader:
                    images=images.to(device_choice)
                    labels=labels.to(device_choice)
                    logps=model.forward(images)
                    loss=criterion(logps,labels)
                    valid_loss=valid_loss+loss.item()
                    ps=torch.exp(logps)
                    top_ps, top_class=ps.topk(1,dim=1)
                    equality=top_class==labels.view(*top_class.shape)
                    accuracy=accuracy+torch.mean(equality.type(torch.FloatTensor)).item()
                    
                    print(f"Num {num+1}/{nums}.. "
                      f"Train loss: {present_loss/screen_every:.3f}.. "
                      f"Valid loss: {valid_loss/len(valid_dataloader):.3f}.. "
                      f"Valid accuracy: {accuracy/len(valid_dataloader):.3f}")

            present_loss=0
            model.train()
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.torch/models/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:00<00:00, 52705018.16it/s]
# Num 1/10.. Train loss: 7.228.. Valid loss: 0.382.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 7.228.. Valid loss: 0.748.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 7.228.. Valid loss: 1.146.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 7.228.. Valid loss: 1.483.. Valid accuracy: 0.004
# Num 1/10.. Train loss: 7.228.. Valid loss: 1.805.. Valid accuracy: 0.011
# Num 1/10.. Train loss: 7.228.. Valid loss: 2.161.. Valid accuracy: 0.019
# Num 1/10.. Train loss: 7.228.. Valid loss: 2.516.. Valid accuracy: 0.019
# Num 1/10.. Train loss: 7.228.. Valid loss: 2.866.. Valid accuracy: 0.024
# Num 1/10.. Train loss: 7.228.. Valid loss: 3.226.. Valid accuracy: 0.024
# Num 1/10.. Train loss: 7.228.. Valid loss: 3.582.. Valid accuracy: 0.024
# Num 1/10.. Train loss: 7.228.. Valid loss: 3.946.. Valid accuracy: 0.024
# Num 1/10.. Train loss: 7.228.. Valid loss: 4.305.. Valid accuracy: 0.026
# Num 1/10.. Train loss: 7.228.. Valid loss: 4.657.. Valid accuracy: 0.026
# Num 1/10.. Train loss: 4.522.. Valid loss: 0.378.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.522.. Valid loss: 0.739.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.522.. Valid loss: 1.110.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.522.. Valid loss: 1.458.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.522.. Valid loss: 1.783.. Valid accuracy: 0.005
# Num 1/10.. Train loss: 4.522.. Valid loss: 2.106.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 2.454.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 2.813.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 3.144.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 3.482.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 3.827.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 4.155.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.522.. Valid loss: 4.497.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.523.. Valid loss: 0.377.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.523.. Valid loss: 0.741.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.523.. Valid loss: 1.118.. Valid accuracy: 0.000
# Num 1/10.. Train loss: 4.523.. Valid loss: 1.467.. Valid accuracy: 0.001
# Num 1/10.. Train loss: 4.523.. Valid loss: 1.797.. Valid accuracy: 0.005
# Num 1/10.. Train loss: 4.523.. Valid loss: 2.115.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.523.. Valid loss: 2.466.. Valid accuracy: 0.038
# Num 1/10.. Train loss: 4.523.. Valid loss: 2.814.. Valid accuracy: 0.041
# Num 1/10.. Train loss: 4.523.. Valid loss: 3.137.. Valid accuracy: 0.041
# Num 1/10.. Train loss: 4.523.. Valid loss: 3.473.. Valid accuracy: 0.041
# Num 1/10.. Train loss: 4.523.. Valid loss: 3.813.. Valid accuracy: 0.041
# Num 1/10.. Train loss: 4.523.. Valid loss: 4.140.. Valid accuracy: 0.041
# Num 1/10.. Train loss: 4.523.. Valid loss: 4.476.. Valid accuracy: 0.042
# Num 2/10.. Train loss: 4.526.. Valid loss: 0.379.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.526.. Valid loss: 0.745.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.526.. Valid loss: 1.125.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.526.. Valid loss: 1.478.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.526.. Valid loss: 1.805.. Valid accuracy: 0.004
# Num 2/10.. Train loss: 4.526.. Valid loss: 2.124.. Valid accuracy: 0.037
# Num 2/10.. Train loss: 4.526.. Valid loss: 2.470.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 2.831.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 3.148.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 3.476.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 3.815.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 4.139.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.526.. Valid loss: 4.477.. Valid accuracy: 0.038
# Num 2/10.. Train loss: 4.512.. Valid loss: 0.382.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.512.. Valid loss: 0.747.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.512.. Valid loss: 1.130.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.512.. Valid loss: 1.474.. Valid accuracy: 0.001
# Num 2/10.. Train loss: 4.512.. Valid loss: 1.797.. Valid accuracy: 0.006
# Num 2/10.. Train loss: 4.512.. Valid loss: 2.112.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 2.459.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 2.821.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 3.133.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 3.455.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 3.797.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 4.123.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.512.. Valid loss: 4.458.. Valid accuracy: 0.040
# Num 2/10.. Train loss: 4.485.. Valid loss: 0.384.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.485.. Valid loss: 0.754.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.485.. Valid loss: 1.135.. Valid accuracy: 0.000
# Num 2/10.. Train loss: 4.485.. Valid loss: 1.465.. Valid accuracy: 0.004
# Num 2/10.. Train loss: 4.485.. Valid loss: 1.780.. Valid accuracy: 0.010
# Num 2/10.. Train loss: 4.485.. Valid loss: 2.100.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 2.449.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 2.810.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 3.124.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 3.440.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 3.780.. Valid accuracy: 0.043
# Num 2/10.. Train loss: 4.485.. Valid loss: 4.106.. Valid accuracy: 0.044
# Num 2/10.. Train loss: 4.485.. Valid loss: 4.453.. Valid accuracy: 0.044
# Num 3/10.. Train loss: 4.503.. Valid loss: 0.383.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.503.. Valid loss: 0.751.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.503.. Valid loss: 1.136.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.503.. Valid loss: 1.488.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.503.. Valid loss: 1.835.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.503.. Valid loss: 2.155.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 2.509.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 2.870.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 3.181.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 3.492.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 3.829.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 4.157.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.503.. Valid loss: 4.505.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.504.. Valid loss: 0.383.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 0.752.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 1.138.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 1.490.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 1.843.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 2.164.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 2.517.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 2.878.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.504.. Valid loss: 3.192.. Valid accuracy: 0.005
# Num 3/10.. Train loss: 4.504.. Valid loss: 3.501.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.504.. Valid loss: 3.839.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.504.. Valid loss: 4.162.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.504.. Valid loss: 4.510.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.501.. Valid loss: 0.387.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 0.755.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 1.144.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 1.490.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 1.838.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 2.159.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 2.508.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 2.871.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.501.. Valid loss: 3.183.. Valid accuracy: 0.005
# Num 3/10.. Train loss: 4.501.. Valid loss: 3.495.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.501.. Valid loss: 3.834.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.501.. Valid loss: 4.158.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.501.. Valid loss: 4.500.. Valid accuracy: 0.025
# Num 3/10.. Train loss: 4.544.. Valid loss: 0.386.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.544.. Valid loss: 0.753.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.544.. Valid loss: 1.137.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.544.. Valid loss: 1.486.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.544.. Valid loss: 1.828.. Valid accuracy: 0.000
# Num 3/10.. Train loss: 4.544.. Valid loss: 2.147.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 2.504.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 2.866.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 3.178.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 3.489.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 3.827.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 4.155.. Valid accuracy: 0.034
# Num 3/10.. Train loss: 4.544.. Valid loss: 4.498.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 0.384.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.497.. Valid loss: 0.755.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.497.. Valid loss: 1.138.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.497.. Valid loss: 1.491.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.497.. Valid loss: 1.832.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.497.. Valid loss: 2.148.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 2.504.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 2.868.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 3.173.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 3.484.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 3.825.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 4.154.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.497.. Valid loss: 4.499.. Valid accuracy: 0.034
# Num 4/10.. Train loss: 4.512.. Valid loss: 0.383.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 0.751.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 1.134.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 1.480.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 1.819.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 2.141.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 2.492.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 2.856.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.512.. Valid loss: 3.163.. Valid accuracy: 0.005
# Num 4/10.. Train loss: 4.512.. Valid loss: 3.472.. Valid accuracy: 0.025
# Num 4/10.. Train loss: 4.512.. Valid loss: 3.818.. Valid accuracy: 0.025
# Num 4/10.. Train loss: 4.512.. Valid loss: 4.149.. Valid accuracy: 0.025
# Num 4/10.. Train loss: 4.512.. Valid loss: 4.499.. Valid accuracy: 0.025
# Num 4/10.. Train loss: 4.513.. Valid loss: 0.386.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.513.. Valid loss: 0.755.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.513.. Valid loss: 1.141.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.513.. Valid loss: 1.485.. Valid accuracy: 0.000
# Num 4/10.. Train loss: 4.513.. Valid loss: 1.822.. Valid accuracy: 0.002
# Num 4/10.. Train loss: 4.513.. Valid loss: 2.140.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 2.493.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 2.855.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 3.167.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 3.479.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 3.820.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 4.148.. Valid accuracy: 0.036
# Num 4/10.. Train loss: 4.513.. Valid loss: 4.495.. Valid accuracy: 0.036
# Num 5/10.. Train loss: 4.519.. Valid loss: 0.387.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.519.. Valid loss: 0.756.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.519.. Valid loss: 1.144.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.519.. Valid loss: 1.493.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.519.. Valid loss: 1.831.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.519.. Valid loss: 2.151.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.519.. Valid loss: 2.508.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.519.. Valid loss: 2.867.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.519.. Valid loss: 3.175.. Valid accuracy: 0.006
# Num 5/10.. Train loss: 4.519.. Valid loss: 3.485.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.519.. Valid loss: 3.824.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.519.. Valid loss: 4.150.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.519.. Valid loss: 4.488.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.513.. Valid loss: 0.387.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.513.. Valid loss: 0.756.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.513.. Valid loss: 1.142.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.513.. Valid loss: 1.492.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.513.. Valid loss: 1.830.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.513.. Valid loss: 2.156.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.513.. Valid loss: 2.509.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.513.. Valid loss: 2.872.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.513.. Valid loss: 3.181.. Valid accuracy: 0.006
# Num 5/10.. Train loss: 4.513.. Valid loss: 3.487.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.513.. Valid loss: 3.828.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.513.. Valid loss: 4.154.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.513.. Valid loss: 4.490.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.523.. Valid loss: 0.386.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.523.. Valid loss: 0.756.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.523.. Valid loss: 1.139.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.523.. Valid loss: 1.488.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.523.. Valid loss: 1.825.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.523.. Valid loss: 2.146.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.523.. Valid loss: 2.501.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.523.. Valid loss: 2.865.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.523.. Valid loss: 3.178.. Valid accuracy: 0.006
# Num 5/10.. Train loss: 4.523.. Valid loss: 3.486.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.523.. Valid loss: 3.825.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.523.. Valid loss: 4.153.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.523.. Valid loss: 4.494.. Valid accuracy: 0.026
# Num 5/10.. Train loss: 4.494.. Valid loss: 0.385.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.494.. Valid loss: 0.753.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.494.. Valid loss: 1.139.. Valid accuracy: 0.000
# Num 5/10.. Train loss: 4.494.. Valid loss: 1.483.. Valid accuracy: 0.001
# Num 5/10.. Train loss: 4.494.. Valid loss: 1.810.. Valid accuracy: 0.006
# Num 5/10.. Train loss: 4.494.. Valid loss: 2.123.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 2.478.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 2.841.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 3.153.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 3.467.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 3.806.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 4.129.. Valid accuracy: 0.040
# Num 5/10.. Train loss: 4.494.. Valid loss: 4.474.. Valid accuracy: 0.040
# Num 6/10.. Train loss: 4.515.. Valid loss: 0.387.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 0.755.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.140.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.484.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.832.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.152.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.509.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.871.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.183.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.494.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.832.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 4.158.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 4.504.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 0.388.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 0.756.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.144.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.486.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 1.830.. Valid accuracy: 0.000
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.151.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.507.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 2.868.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.187.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.498.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 3.832.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 4.156.. Valid accuracy: 0.034
# Num 6/10.. Train loss: 4.515.. Valid loss: 4.505.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 0.385.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.547.. Valid loss: 0.756.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.547.. Valid loss: 1.140.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.547.. Valid loss: 1.490.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.547.. Valid loss: 1.833.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.547.. Valid loss: 2.146.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 2.499.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 2.860.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 3.175.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 3.485.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 3.826.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 4.153.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.547.. Valid loss: 4.498.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.499.. Valid loss: 0.387.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 0.755.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 1.139.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 1.492.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 1.838.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 2.151.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 2.502.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 2.862.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.499.. Valid loss: 3.173.. Valid accuracy: 0.005
# Num 7/10.. Train loss: 4.499.. Valid loss: 3.481.. Valid accuracy: 0.025
# Num 7/10.. Train loss: 4.499.. Valid loss: 3.825.. Valid accuracy: 0.025
# Num 7/10.. Train loss: 4.499.. Valid loss: 4.153.. Valid accuracy: 0.025
# Num 7/10.. Train loss: 4.499.. Valid loss: 4.500.. Valid accuracy: 0.025
# Num 7/10.. Train loss: 4.521.. Valid loss: 0.385.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.521.. Valid loss: 0.754.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.521.. Valid loss: 1.141.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.521.. Valid loss: 1.489.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.521.. Valid loss: 1.833.. Valid accuracy: 0.000
# Num 7/10.. Train loss: 4.521.. Valid loss: 2.150.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 2.503.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 2.864.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 3.178.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 3.488.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 3.830.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 4.157.. Valid accuracy: 0.034
# Num 7/10.. Train loss: 4.521.. Valid loss: 4.502.. Valid accuracy: 0.034

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
